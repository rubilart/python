# %%
import pandas as pd
import numpy as np

url='https://raw.githubusercontent.com/Yorko/mlcourse_open/master/data/mlbootcamp5_train.csv'
df = pd.read_csv(url,';')
df.head(100)
#df['age']/365
# Out:
#      id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0     0  18393       2     168    62.0    110     80            1     1
# 1     1  20228       1     156    85.0    140     90            3     1
# 2     2  18857       1     165    64.0    130     70            3     1
# 3     3  17623       2     169    82.0    150    100            1     1
# 4     4  17474       1     156    56.0    100     60            1     1
# 5     8  21914       1     151    67.0    120     80            2     2
# 6     9  22113       1     157    93.0    130     80            3     1
# 7    12  22584       2     178    95.0    130     90            3     3
# 8    13  17668       1     158    71.0    110     70            1     1
# 9    14  19834       1     164    68.0    110     60            1     1
# 10   15  22530       1     169    80.0    120     80            1     1
# 11   16  18815       2     173    60.0    120     80            1     1
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
# id             70000 non-null int64
# age            70000 non-null int64
# gender         70000 non-null int64
# height         70000 non-null int64
# weight         70000 non-null float64
# ap_hi          70000 non-null int64
# ap_lo          70000 non-null int64
# cholesterol    70000 non-null int64
# gluc           70000 non-null int64
# smoke          70000 non-null int64
# alco           70000 non-null int64
# active         70000 non-null int64
# cardio         70000 non-null int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB
# None

# %%
df[df['gender']==1]['height'].mean()
# Out:
# 161.35561168460356

# %%
df.groupby(by='gender')['height'].mean()
# Out:
# gender
# 1    161.355612
# 2    169.947895
# Name: height, dtype: float64

# %%
df.groupby(by='gender')['id'].count()
# Out:
# gender
# 1    45530
# 2    24470
# Name: id, dtype: int64

# %%
#1 - Women, 2-Men
df[df['gender']==1][df['alco']==1]['id'].count()
# Out:
# C:\DataScience\Anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 1161

# %%
df[df['gender']==1][df['alco']==1]['id'].count()/df[df['gender']==1]['id'].count()
# Out:
# C:\DataScience\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.025499670546892159

# %%
df[df['gender']==2][df['alco']==1]['id'].count()/df[df['gender']==2]['id'].count()
# Out:
# C:\DataScience\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.10637515324887617

# %%
#Men alco more

# %% [markdown]
# Вопрос 3 (1 балл). Во сколько раз (округленно, round) процент курящих среди мужчин больше, чем процент курящих среди женщин (по крайней мере, по этим анкетным данным)?

# %%
cnt_w = df[df['gender']==1][df['smoke']==1]['id'].count()/df[df['gender']==1]['id'].count()
cnt_m = df[df['gender']==2][df['smoke']==1]['id'].count()/df[df['gender']==2]['id'].count()
cnt_m/cnt_w
# Out:
# C:\DataScience\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\DataScience\Anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 12.257833097333833

# %% [markdown]
# Вопрос 4 (1 балл). Вы наверняка заметили, что значения возраста какие-то странные. Догадайтесь, в чём здесь измеряется возраст, и ответьте, на сколько месяцев (примерно) отличаются медианные значения возраста курящих и некурящих.

# %%
df.groupby(by='smoke')['age'].mean()
# Out:
# smoke
# 0    19505.400730
# 1    19090.836927
# Name: age, dtype: float64

# %%
df.groupby(by='smoke')['age'].apply(np.median)
# Out:
# smoke
# 0    19722.0
# 1    19125.0
# Name: age, dtype: float64

# %%
(19722.0-19125.0)/365.25*12
# Out:
# 19.613963039014372

# %% [markdown]
# Вопрос 5 (2 балла). В статье на Википедии про сердечно-сосудистый риск показана шкала SCORE для расчёта риска смерти от сердечно-сосудистого заболевания в ближайшие 10 лет. Вот она:

# %%
df['age_years']=round(df['age']/365.25)
df.head()

# %%
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years
# 0     0       1       0       50.0
# 1     0       1       1       55.0
# 2     0       0       1       52.0
# 3     0       1       1       48.0
# 4     0       0       0       48.0

# %%
df1=df[(df['age_years']>=60) & (df['age_years']<=64) & (df['gender']==2) & df['smoke']==1]#['ap_hi','cholesterol','cardio']
df1.head()
# Out:
#       id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 19    29  21755       2     162    56.0    120     70            1     1
# 38    52  23388       2     162    72.0    130     80            1     1
# 67    90  22099       2     171    97.0    150    100            3     1
# 177  240  21848       2     170    69.0    120     80            1     1
# 182  248  22671       2     174    74.0    130     80            3     1
#
#      smoke  alco  active  cardio  age_years
# 19       1     0       1       0       60.0
# 38       1     0       1       1       64.0
# 67       1     0       1       1       61.0
# 177      1     1       1       0       60.0
# 182      1     0       1       1       62.0

# %%
df_120=df1[(df1['ap_hi']<120) & (df1['cholesterol']==1)]
df_180=df1[(df1['ap_hi']>=160) &(df1['ap_hi']<180) & (df1['cholesterol']==3)]

# %%
df_120['cardio'].value_counts(normalize=True)
# Out:
# 0    0.736842
# 1    0.263158
# Name: cardio, dtype: float64

# %%
df_180['cardio'].value_counts(normalize=True)
# Out:
# 1    0.863636
# 0    0.136364
# Name: cardio, dtype: float64

# %%
round(0.863636/0.263158)
# Out:
# 3

# %% [markdown]
# Вопрос 6 (2 балла). Постройте новый признак – BMI (Body Mass Index). Для этого надо вес в килограммах поделить на квадрат роста в метрах. Нормальными считаются значения BMI от 18.5 до 25. Выберите верные утверждения.

# %%
df['BMI']= df['weight']/((df['height']/100)**2)
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio  age_years        BMI
# 0     0       1       0       50.0  21.967120
# 1     0       1       1       55.0  34.927679
# 2     0       0       1       52.0  23.507805
# 3     0       1       1       48.0  28.710479
# 4     0       0       0       48.0  23.011177

# %% [markdown]
# 6.1. Медианный BMI по выборке превышает норму
# YES

# %%
median=np.median(df['BMI'])
median
# Out:
# 26.374068120774975

# %% [markdown]
# 6.2 У женщин в среднем BMI ниже, чем у мужчин
# NO

# %%
d = {1 : 'Woman', 2: 'Man'}
df['gender_str'] = df['gender'].map(d)
df.groupby(by=['gender_str'])['BMI'].mean()
# Out:
# gender_str
# Man      26.754442
# Woman    27.987583
# Name: BMI, dtype: float64

# %% [markdown]
# 6.3 У здоровых в среднем BMI выше, чем у больных
# NO

# %%
df.groupby(by=['cardio'])['BMI'].mean()
# Out:
# cardio
# 0    26.548175
# 1    28.566061
# Name: BMI, dtype: float64

# %% [markdown]
# 6.4. В сегменте здоровых и непьющих мужчин в среднем BMI ближе к норме, чем в сегменте здоровых и непьющих женщин
# NO

# %%
df[(df['alco']==0)&(df['cardio']==0)].groupby(by=['gender_str'])['BMI'].mean()
# Out:
# gender_str
# Man      25.872638
# Woman    26.845407
# Name: BMI, dtype: float64

# %% [markdown]
# .........................

# %% [markdown]
# Вопрос 7 (2 балла). Можно заметить, что данные не особо-то чистые, много в них всякой "грязи" и неточностей. Еще лучше мы это увидим, когда обсудим визуализацию данных.
#
# Отфильтруйте следующие сегменты пациентов (считаем это ошибками в данных)
#
#     указанное нижнее значение артериального давления строго выше верхнего
#     рост строго меньше 2.5%-перцентили или строго больше 97.5%-перцентили (используйте pd.Series.quantile, если не знаете, что это такое – прочитайте)
#     вес строго меньше 2.5%-перцентили или строго больше 97.5%-перцентили
#
# Это вовсе не вся чистка данных, которую можно было проделать, но пока остановимся на этом.
#
# Сколько процентов данных (округленно, round) мы выбросили?

# %%
df=df[df['ap_hi']>df['ap_lo']]
df.count()
# Out:
# id             68764
# age            68764
# gender         68764
# height         68764
# weight         68764
# ap_hi          68764
# ap_lo          68764
# cholesterol    68764
# gluc           68764
# smoke          68764
# alco           68764
# active         68764
# cardio         68764
# age_years      68764
# BMI            68764
# gender_str     68764
# dtype: int64
